# %%
import numpy as np
import re

# %%
fn = "day4.txt"
data = open(fn).read().strip()

ans = 0

prev_num_occ = 1
num_occ_dict = dict()
num_card_dict = dict()
for i, line in enumerate(data.split("\n")):
    # print('='*20)
    card_mult = 1
    num_occ = 0
    cur_score = 0
    # print(line[10:])
    # print(line[8:])
    win_nums = line[10:].split('|')[0].strip().split()
    my_nums = line[10:].split('|')[1].strip().split()
    # win_nums = line[8:].split('|')[0].strip().split()
    # my_nums = line[8:].split('|')[1].strip().split()
    win_nums_dict = dict()
    for my_n in my_nums:
        if my_n in win_nums:
            num_occ += 1
    num_occ_dict[i] = num_occ 
    num_card_dict[i] = 1 

    # for key in num_occ_dict:
    #     card_chk = num_card_dict[key]
    #     if num_occ_dict[key]-i<0: #Not enough matches to make it to card num
    #         continue
    #     else:
    #         while card_chk >= 0: 
    #             num_card_dict[i] += 1
    #             card_chk -= 1
for key in num_occ_dict:
    card_chk = num_card_dict[key]
    # print("="*8)
    # print("key: ", key)
    # print("num cards: ", num_card_dict)
    # print("num occ: ", num_occ_dict)
    # print(card_chk)
    while card_chk > 0:
        for card_id in range(key+1, num_occ_dict[key]+1+key):
            # print(card_id)
            num_card_dict[card_id]+=1
        card_chk -= 1
# print(num_occ_dict)    
# print(num_card_dict)
for key in num_card_dict:
    ans += num_card_dict[key]
print(ans)
# Out:
# ...
# 10378710

# %%
f = [1,23,5,6,2,547, 23, 5, 3,3,3,6,7]
print(f)
set(f)

# %%
ans
# Out:
# 10378710

# %%
for i in range(1):
    print(i)
# Out:
# 0
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
